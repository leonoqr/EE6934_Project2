# %%
# Imports
import os
import torch
import numpy as np
import re

# Training/Test Set Creation - to use later
from sklearn.model_selection import StratifiedShuffleSplit

# Dataset Creation
from torch.utils.data import Dataset, DataLoader, Subset
import torchvision.transforms as transforms

# Model Training and Definition
from torch import nn
from torch import optim
from torch.optim.lr_scheduler import CosineAnnealingLR, ReduceLROnPlateau
import trainutils

# %%
# Specify directories
frame_folder = "./data/frames"

# %% [markdown]
# # Create Training and Test Sets

# %% [markdown]
# ## Define classes and preview

# %%
# Define label dictionary - 20 classes
syncs = [  "0-100 ms", "101-200 ms", "201-300 ms", "301-400 ms", "401-500 ms", 
         "501-600 ms", "601-700 ms", "701-800 ms", "801-900 ms", "901-1000 ms" ]
sync_dict = {}

count = 0
for sync_val in syncs:
    sync_dict[sync_val] = count
    count += 1

# preview dictionary
sync_dict
# Out:
# {'0-100 ms': 0,
#  '101-200 ms': 1,
#  '201-300 ms': 2,
#  '301-400 ms': 3,
#  '401-500 ms': 4,
#  '501-600 ms': 5,
#  '601-700 ms': 6,
#  '701-800 ms': 7,
#  '801-900 ms': 8,
#  '901-1000 ms': 9}

# %% [markdown]
# ## Load training data

# %%
# Construct X = folder names, y = the label

vf_list = os.listdir(frame_folder)

X_paths = [] # paths of segment folders
y = [] # designated label

for vf_folder in vf_list:
    
    # Create path to video
    vf_path = os.path.join(frame_folder, vf_folder)
    print("Current Video: "+ vf_folder)
    
    # Get individual segment folder
    segfolder_list = os.listdir(vf_path)
    
    # Check every segment folder
    for seg_folder in segfolder_list:
        
        #print(seg_folder)
        x_path = os.path.join(vf_path, seg_folder)
        #print(x_path)
        X_paths.append(x_path)
        
        # Extract class label from folder name
        label = int(seg_folder.split("_")[2])
        #print(label)
        y.append(label)
# Out:
# Current Video: video1
# Current Video: video2
# Current Video: video3
# Current Video: video4

# %%
# Preview Data distribution
from collections import Counter
Counter(y)
# Out:
# Counter({1: 54, 2: 49, 4: 50, 5: 51, 8: 52, 9: 52, 0: 48, 3: 50, 6: 48, 7: 50})

# %%
# Split into training and test sets
splitter = StratifiedShuffleSplit(n_splits = 2, test_size = 0.1, random_state = 0)
train_set, test_set = next(splitter.split(X_paths, y))

# Training Set
train_X_paths = [X_paths[i] for i in train_set]
train_ys = [y[i] for i in train_set]
print("Training Set: ({0},{1})".format(len(train_X_paths), len(train_ys)))

# Test Set
test_X_paths = [X_paths[i] for i in test_set]
test_ys = [y[i] for i in test_set]
print("Test Set: ({0},{1})".format(len(test_X_paths), len(test_ys)))
#print(test_X_paths)
# Out:
# Training Set: (453,453)
# Test Set: (51,51)

# %% [markdown]
# # Create Pytorch Dataset

# %%
# Set seeds for reproducibility
np.random.seed(4139)
torch.manual_seed(4139)

# %%
# Create Dataset Class
class SyncDataset(Dataset):
    
    def __init__(self, X, y, transform=None):
        self.transform = transform
        self.X = X
        self.y = y
    
    # Returns length
    def __len__(self):
        return len(self.X)
    
    # Returns X feature array and y value
    def __getitem__(self, idx):
        
        # Load npz file
        npz_path = self.X[idx]+'/features.npz'
        #print(npz_path)
        data = np.load(npz_path)
        X_feat = data['feature_array']
        
        # Transform if needed
        
        # Convert X to tensor
        X_tensor = torch.from_numpy(X_feat).float()
        
        return X_tensor, self.y[idx] # y_tensor

# %%
# Define Transformer - may need it for later, unused for now
transformer = transforms.Compose([
    transforms.ToTensor() # Add min-max scaler, or an normalizer
])

# %%
# Define Training Dataset 
training_dataset = SyncDataset(X = train_X_paths, y = train_ys, transform = transformer)
print(len(training_dataset))

# Define Test Dataset
testing_dataset = SyncDataset(X = test_X_paths, y = test_ys, transform = transformer)
print(len(testing_dataset))
# Out:
# 453
# 51

# %%
# Grab a row to see contents
sample_X, sample_y = testing_dataset[3]
sample_X.shape, sample_y
# Out:
# (torch.Size([20, 168]), 5)

# %% [markdown]
# # Model Definition

# %%
class SyncRNN(nn.Module):
    
    def __init__(self, params_model):
        
        super(SyncRNN, self).__init__()
        
        # Import Model Parameters
        num_classes = params_model["num_classes"]
        dr_rate = params_model["dr_rate"] # dropout rate
        rnn_hidden_size = params_model["rnn_hidden_size"]
        rnn_num_layers = params_model["rnn_num_layers"]
        num_features = 168
        
        # Define Model Structure
        self.dropout = nn.Dropout(dr_rate) # - do we need this?
        self.rnn = nn.LSTM(num_features, rnn_hidden_size, rnn_num_layers)
        self.fc1 = nn.Linear(rnn_hidden_size, num_classes)
        
    def forward(self, x):
        
        # batch count, frame count, feature size
        #print(x.shape) # torch.Size([20, 168])
        #print(x[0].shape) # torch.Size([168])
        frame_count, feature_size = x.shape
        frame_idx = 0
        
        # Reshape the frame
        shaped_frame = x[frame_idx].view(1, 1, feature_size)
        
        # Feed the first frame into the rnn
        output, (hn, cn) = self.rnn(shaped_frame)
        
        # Feed the rest of the frames 
        for frame_idx in range(1, frame_count):
            shaped_frame = x[frame_idx].view(1, 1, feature_size)
            output, (hn, cn) = self.rnn(shaped_frame, (hn, cn))
        
        #output = self.dropout(output[:,-1])
        output = self.fc1(output)
        return output

# %% [markdown]
# # Model Testing

# %%
# Setup model with parameters
model_params = {
    "num_classes": 10,
    "dr_rate": 0.1,
    "rnn_num_layers": 1,
    "rnn_hidden_size": 500,
}
model = SyncRNN(model_params)

# %%
# Load the weights and set to GPU
weight_path = "./models/weights_kpf_bestlossacc.pt"
model.load_state_dict(torch.load(weight_path))

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
model.eval()
with torch.no_grad():
    count = 0
    correct_count = 0
    for test_X, test_y in testing_dataset:
        output = model(test_X.to(device)).cpu()
        test_pred = output.argmax().item()
        print("{}. Predicted: {} Actual: {}".format(count, test_pred, test_y))
        if test_pred == test_y:
            correct_count += 1
        count += 1
print("Total Score: {0}/51 = {1:.2f}%".format(correct_count, (correct_count/51)*100))
# Out:
# 0. Predicted: 1 Actual: 3
# 1. Predicted: 8 Actual: 6
# 2. Predicted: 1 Actual: 1
# 3. Predicted: 8 Actual: 5
# 4. Predicted: 1 Actual: 1
# 5. Predicted: 1 Actual: 2
# 6. Predicted: 1 Actual: 5
# 7. Predicted: 1 Actual: 1
# 8. Predicted: 1 Actual: 0
# 9. Predicted: 1 Actual: 8
# 10. Predicted: 1 Actual: 9
# 11. Predicted: 1 Actual: 1
# 12. Predicted: 1 Actual: 9
# 13. Predicted: 1 Actual: 7
# 14. Predicted: 9 Actual: 8
# 15. Predicted: 8 Actual: 7
# 16. Predicted: 1 Actual: 6
# 17. Predicted: 1 Actual: 4
# 18. Predicted: 9 Actual: 9
# 19. Predicted: 8 Actual: 3
# 20. Predicted: 9 Actual: 8
# 21. Predicted: 8 Actual: 2
# 22. Predicted: 1 Actual: 0
# 23. Predicted: 9 Actual: 6
# 24. Predicted: 1 Actual: 8
# 25. Predicted: 1 Actual: 9
# 26. Predicted: 1 Actual: 2
# 27. Predicted: 1 Actual: 5
# 28. Predicted: 1 Actual: 9
# 29. Predicted: 9 Actual: 4
# 30. Predicted: 1 Actual: 6
# 31. Predicted: 8 Actual: 7
# 32. Predicted: 1 Actual: 4
# 33. Predicted: 9 Actual: 7
# 34. Predicted: 1 Actual: 3
# 35. Predicted: 8 Actual: 4
# 36. Predicted: 8 Actual: 6
# 37. Predicted: 1 Actual: 1
# 38. Predicted: 1 Actual: 5
# 39. Predicted: 1 Actual: 3
# 40. Predicted: 9 Actual: 7
# 41. Predicted: 8 Actual: 8
# 42. Predicted: 1 Actual: 2
# 43. Predicted: 1 Actual: 2
# 44. Predicted: 1 Actual: 0
# 45. Predicted: 8 Actual: 3
# 46. Predicted: 1 Actual: 0
# 47. Predicted: 1 Actual: 5
# 48. Predicted: 1 Actual: 4
# 49. Predicted: 1 Actual: 0
# 50. Predicted: 1 Actual: 1
# Total Score: 8/51 = 15.69%

# %%
model.eval()
with torch.no_grad():
    count = 0
    correct_count = 0
    for train_X, train_y in training_dataset:
        output = model(train_X.to(device)).cpu()
        train_pred = output.argmax().item()
        print("{}. Predicted: {} Actual: {}".format(count, train_pred, train_y))
        if train_pred == train_y:
            correct_count += 1
        count += 1
print("Total Score: {0}/453 = {1:.2f}%".format(correct_count, (correct_count/453)*100))
# Out:
# 0. Predicted: 1 Actual: 6
# 1. Predicted: 9 Actual: 7
# 2. Predicted: 1 Actual: 6
# 3. Predicted: 1 Actual: 2
# 4. Predicted: 1 Actual: 5
# 5. Predicted: 1 Actual: 5
# 6. Predicted: 1 Actual: 5
# 7. Predicted: 1 Actual: 0
# 8. Predicted: 1 Actual: 4
# 9. Predicted: 1 Actual: 0
# 10. Predicted: 1 Actual: 3
# 11. Predicted: 8 Actual: 9
# 12. Predicted: 1 Actual: 9
# 13. Predicted: 1 Actual: 7
# 14. Predicted: 1 Actual: 3
# 15. Predicted: 8 Actual: 9
# 16. Predicted: 9 Actual: 5
# 17. Predicted: 1 Actual: 8
# 18. Predicted: 8 Actual: 5
# 19. Predicted: 9 Actual: 9
# 20. Predicted: 1 Actual: 5
# 21. Predicted: 1 Actual: 5
# 22. Predicted: 8 Actual: 7
# 23. Predicted: 1 Actual: 1
# 24. Predicted: 1 Actual: 6
# 25. Predicted: 9 Actual: 1
# 26. Predicted: 1 Actual: 3
# 27. Predicted: 1 Actual: 1
# 28. Predicted: 1 Actual: 7
# 29. Predicted: 8 Actual: 5
# 30. Predicted: 1 Actual: 4
# 31. Predicted: 1 Actual: 3
# 32. Predicted: 1 Actual: 2
# 33. Predicted: 1 Actual: 4
# 34. Predicted: 1 Actual: 9
# 35. Predicted: 1 Actual: 1
# 36. Predicted: 9 Actual: 3
# 37. Predicted: 1 Actual: 2
# 38. Predicted: 1 Actual: 8
# 39. Predicted: 9 Actual: 4
# 40. Predicted: 1 Actual: 1
# 41. Predicted: 1 Actual: 4
# 42. Predicted: 8 Actual: 3
# 43. Predicted: 1 Actual: 0
# 44. Predicted: 9 Actual: 9
# 45. Predicted: 1 Actual: 5
# 46. Predicted: 1 Actual: 6
# 47. Predicted: 1 Actual: 8
# 48. Predicted: 8 Actual: 5
# 49. Predicted: 1 Actual: 2
# 50. Predicted: 1 Actual: 8
# 51. Predicted: 8 Actual: 8
# 52. Predicted: 1 Actual: 5
# 53. Predicted: 1 Actual: 9
# 54. Predicted: 8 Actual: 8
# 55. Predicted: 1 Actual: 0
# 56. Predicted: 1 Actual: 1
# 57. Predicted: 8 Actual: 6
# 58. Predicted: 8 Actual: 9
# 59. Predicted: 1 Actual: 2
# 60. Predicted: 1 Actual: 7
# 61. Predicted: 1 Actual: 8
# 62. Predicted: 1 Actual: 5
# 63. Predicted: 9 Actual: 4
# 64. Predicted: 8 Actual: 7
# 65. Predicted: 8 Actual: 4
# 66. Predicted: 1 Actual: 9
# 67. Predicted: 1 Actual: 7
# 68. Predicted: 1 Actual: 0
# 69. Predicted: 1 Actual: 1
# 70. Predicted: 9 Actual: 2
# 71. Predicted: 1 Actual: 5
# 72. Predicted: 1 Actual: 2
# 73. Predicted: 1 Actual: 8
# 74. Predicted: 8 Actual: 8
# 75. Predicted: 1 Actual: 2
# 76. Predicted: 1 Actual: 7
# 77. Predicted: 1 Actual: 3
# 78. Predicted: 8 Actual: 0
# 79. Predicted: 1 Actual: 4
# 80. Predicted: 1 Actual: 1
# 81. Predicted: 1 Actual: 0
# 82. Predicted: 8 Actual: 0
# 83. Predicted: 7 Actual: 7
# 84. Predicted: 8 Actual: 1
# 85. Predicted: 9 Actual: 5
# 86. Predicted: 1 Actual: 8
# 87. Predicted: 1 Actual: 3
# 88. Predicted: 1 Actual: 3
# 89. Predicted: 1 Actual: 7
# 90. Predicted: 1 Actual: 8
# 91. Predicted: 1 Actual: 4
# 92. Predicted: 1 Actual: 0
# 93. Predicted: 1 Actual: 3
# 94. Predicted: 1 Actual: 6
# 95. Predicted: 8 Actual: 5
# 96. Predicted: 9 Actual: 7
# 97. Predicted: 1 Actual: 0
# 98. Predicted: 1 Actual: 5
# 99. Predicted: 9 Actual: 0
# 100. Predicted: 9 Actual: 3
# 101. Predicted: 1 Actual: 0
# 102. Predicted: 1 Actual: 2
# 103. Predicted: 9 Actual: 9
# 104. Predicted: 1 Actual: 0
# 105. Predicted: 1 Actual: 2
# 106. Predicted: 4 Actual: 0
# 107. Predicted: 1 Actual: 4
# 108. Predicted: 9 Actual: 5
# 109. Predicted: 1 Actual: 6
# 110. Predicted: 1 Actual: 0
# 111. Predicted: 8 Actual: 9
# 112. Predicted: 1 Actual: 4
# 113. Predicted: 8 Actual: 7
# 114. Predicted: 1 Actual: 4
# 115. Predicted: 1 Actual: 6
# 116. Predicted: 1 Actual: 6
# 117. Predicted: 1 Actual: 2
# 118. Predicted: 1 Actual: 6
# 119. Predicted: 1 Actual: 1
# 120. Predicted: 1 Actual: 2
# 121. Predicted: 1 Actual: 6
# 122. Predicted: 9 Actual: 5
# 123. Predicted: 1 Actual: 4
# 124. Predicted: 1 Actual: 8
# 125. Predicted: 1 Actual: 1
# 126. Predicted: 1 Actual: 2
# 127. Predicted: 1 Actual: 3
# 128. Predicted: 1 Actual: 5
# 129. Predicted: 9 Actual: 8
# 130. Predicted: 1 Actual: 1
# 131. Predicted: 1 Actual: 9
# 132. Predicted: 9 Actual: 6
# 133. Predicted: 1 Actual: 8
# 134. Predicted: 1 Actual: 7
# 135. Predicted: 1 Actual: 1
# 136. Predicted: 1 Actual: 6
# 137. Predicted: 1 Actual: 3
# 138. Predicted: 9 Actual: 8
# 139. Predicted: 9 Actual: 0
# 140. Predicted: 1 Actual: 6
# 141. Predicted: 1 Actual: 1
# 142. Predicted: 1 Actual: 0
# 143. Predicted: 8 Actual: 5
# 144. Predicted: 8 Actual: 5
# 145. Predicted: 8 Actual: 6
# 146. Predicted: 1 Actual: 8
# 147. Predicted: 9 Actual: 7
# 148. Predicted: 1 Actual: 8
# 149. Predicted: 9 Actual: 9
# 150. Predicted: 1 Actual: 9
# 151. Predicted: 1 Actual: 9
# 152. Predicted: 9 Actual: 2
# 153. Predicted: 1 Actual: 2
# 154. Predicted: 1 Actual: 1
# 155. Predicted: 1 Actual: 0
# 156. Predicted: 1 Actual: 3
# 157. Predicted: 8 Actual: 9
# 158. Predicted: 1 Actual: 8
# 159. Predicted: 1 Actual: 0
# 160. Predicted: 1 Actual: 6
# 161. Predicted: 8 Actual: 6
# 162. Predicted: 1 Actual: 4
# 163. Predicted: 9 Actual: 6
# 164. Predicted: 1 Actual: 7
# 165. Predicted: 1 Actual: 0
# 166. Predicted: 1 Actual: 1
# 167. Predicted: 1 Actual: 6
# 168. Predicted: 1 Actual: 8
# 169. Predicted: 1 Actual: 3
# 170. Predicted: 9 Actual: 9
# 171. Predicted: 1 Actual: 7
# 172. Predicted: 9 Actual: 4
# 173. Predicted: 1 Actual: 1
# 174. Predicted: 1 Actual: 1
# 175. Predicted: 1 Actual: 1
# 176. Predicted: 8 Actual: 6
# 177. Predicted: 8 Actual: 4
# 178. Predicted: 9 Actual: 6
# 179. Predicted: 1 Actual: 0
# 180. Predicted: 1 Actual: 6
# 181. Predicted: 8 Actual: 6
# 182. Predicted: 1 Actual: 0
# 183. Predicted: 1 Actual: 9
# 184. Predicted: 9 Actual: 8
# 185. Predicted: 1 Actual: 7
# 186. Predicted: 1 Actual: 2
# 187. Predicted: 9 Actual: 1
# 188. Predicted: 1 Actual: 9
# 189. Predicted: 1 Actual: 1
# 190. Predicted: 9 Actual: 8
# 191. Predicted: 9 Actual: 4
# 192. Predicted: 1 Actual: 9
# 193. Predicted: 9 Actual: 6
# 194. Predicted: 8 Actual: 8
# 195. Predicted: 8 Actual: 7
# 196. Predicted: 1 Actual: 0
# 197. Predicted: 1 Actual: 0
# 198. Predicted: 9 Actual: 7
# 199. Predicted: 1 Actual: 4
# 200. Predicted: 1 Actual: 3
# 201. Predicted: 1 Actual: 8
# 202. Predicted: 1 Actual: 4
# 203. Predicted: 9 Actual: 8
# 204. Predicted: 1 Actual: 3
# 205. Predicted: 1 Actual: 9
# 206. Predicted: 1 Actual: 5
# 207. Predicted: 1 Actual: 6
# 208. Predicted: 1 Actual: 8
# 209. Predicted: 1 Actual: 6
# 210. Predicted: 1 Actual: 9
# 211. Predicted: 1 Actual: 5
# 212. Predicted: 1 Actual: 5
# 213. Predicted: 9 Actual: 6
# 214. Predicted: 1 Actual: 3
# 215. Predicted: 1 Actual: 3
# 216. Predicted: 1 Actual: 7
# 217. Predicted: 8 Actual: 9
# 218. Predicted: 8 Actual: 5
# 219. Predicted: 1 Actual: 2
# 220. Predicted: 1 Actual: 5
# 221. Predicted: 8 Actual: 9
# 222. Predicted: 9 Actual: 0
# 223. Predicted: 1 Actual: 1
# 224. Predicted: 9 Actual: 1
# 225. Predicted: 1 Actual: 7
# 226. Predicted: 1 Actual: 3
# 227. Predicted: 1 Actual: 4
# 228. Predicted: 1 Actual: 7
# 229. Predicted: 9 Actual: 5
# 230. Predicted: 8 Actual: 6
# 231. Predicted: 1 Actual: 9
# 232. Predicted: 1 Actual: 0
# 233. Predicted: 1 Actual: 6
# 234. Predicted: 1 Actual: 8
# 235. Predicted: 1 Actual: 0
# 236. Predicted: 1 Actual: 7
# 237. Predicted: 1 Actual: 3
# 238. Predicted: 1 Actual: 4
# 239. Predicted: 8 Actual: 5
# 240. Predicted: 1 Actual: 4
# 241. Predicted: 1 Actual: 1
# 242. Predicted: 1 Actual: 1
# 243. Predicted: 8 Actual: 4
# 244. Predicted: 1 Actual: 2
# 245. Predicted: 8 Actual: 3
# 246. Predicted: 1 Actual: 0
# 247. Predicted: 1 Actual: 2
# 248. Predicted: 1 Actual: 3
# 249. Predicted: 1 Actual: 3
# 250. Predicted: 9 Actual: 7
# 251. Predicted: 1 Actual: 5
# 252. Predicted: 1 Actual: 9
# 253. Predicted: 1 Actual: 6
# 254. Predicted: 1 Actual: 0
# 255. Predicted: 9 Actual: 2
# 256. Predicted: 1 Actual: 1
# 257. Predicted: 1 Actual: 9
# 258. Predicted: 8 Actual: 7
# 259. Predicted: 9 Actual: 8
# 260. Predicted: 1 Actual: 5
# 261. Predicted: 1 Actual: 7
# 262. Predicted: 1 Actual: 4
# 263. Predicted: 1 Actual: 0
# 264. Predicted: 1 Actual: 0
# 265. Predicted: 1 Actual: 9
# 266. Predicted: 1 Actual: 0
# 267. Predicted: 9 Actual: 1
# 268. Predicted: 1 Actual: 7
# 269. Predicted: 9 Actual: 7
# 270. Predicted: 1 Actual: 1
# 271. Predicted: 1 Actual: 1
# 272. Predicted: 9 Actual: 3
# 273. Predicted: 1 Actual: 7
# 274. Predicted: 1 Actual: 6
# 275. Predicted: 1 Actual: 2
# 276. Predicted: 1 Actual: 1
# 277. Predicted: 1 Actual: 1
# 278. Predicted: 1 Actual: 6
# 279. Predicted: 1 Actual: 5
# 280. Predicted: 1 Actual: 5
# 281. Predicted: 1 Actual: 3
# 282. Predicted: 1 Actual: 9
# 283. Predicted: 9 Actual: 1
# 284. Predicted: 1 Actual: 2
# 285. Predicted: 1 Actual: 1
# 286. Predicted: 9 Actual: 8
# 287. Predicted: 1 Actual: 2
# 288. Predicted: 1 Actual: 1
# 289. Predicted: 9 Actual: 9
# 290. Predicted: 1 Actual: 6
# 291. Predicted: 1 Actual: 2
# 292. Predicted: 1 Actual: 0
# 293. Predicted: 1 Actual: 3
# 294. Predicted: 9 Actual: 2
# 295. Predicted: 1 Actual: 1
# 296. Predicted: 1 Actual: 5
# 297. Predicted: 1 Actual: 3
# 298. Predicted: 1 Actual: 5
# 299. Predicted: 9 Actual: 9
# 300. Predicted: 1 Actual: 6
# 301. Predicted: 8 Actual: 3
# 302. Predicted: 9 Actual: 1
# 303. Predicted: 1 Actual: 9
# 304. Predicted: 1 Actual: 2
# 305. Predicted: 1 Actual: 3
# 306. Predicted: 1 Actual: 8
# 307. Predicted: 1 Actual: 0
# 308. Predicted: 1 Actual: 4
# 309. Predicted: 1 Actual: 9
# 310. Predicted: 1 Actual: 9
# 311. Predicted: 1 Actual: 8
# 312. Predicted: 1 Actual: 5
# 313. Predicted: 1 Actual: 8
# 314. Predicted: 8 Actual: 3
# 315. Predicted: 1 Actual: 4
# 316. Predicted: 1 Actual: 1
# 317. Predicted: 1 Actual: 2
# 318. Predicted: 1 Actual: 6
# 319. Predicted: 9 Actual: 4
# 320. Predicted: 1 Actual: 1
# 321. Predicted: 9 Actual: 7
# 322. Predicted: 1 Actual: 1
# 323. Predicted: 9 Actual: 9
# 324. Predicted: 1 Actual: 4
# 325. Predicted: 1 Actual: 9
# 326. Predicted: 1 Actual: 2
# 327. Predicted: 1 Actual: 3
# 328. Predicted: 8 Actual: 8
# 329. Predicted: 1 Actual: 0
# 330. Predicted: 8 Actual: 6
# 331. Predicted: 1 Actual: 5
# 332. Predicted: 1 Actual: 5
# 333. Predicted: 9 Actual: 5
# 334. Predicted: 1 Actual: 5
# 335. Predicted: 1 Actual: 0
# 336. Predicted: 9 Actual: 1
# 337. Predicted: 1 Actual: 3
# 338. Predicted: 1 Actual: 7
# 339. Predicted: 1 Actual: 4
# 340. Predicted: 1 Actual: 8
# 341. Predicted: 1 Actual: 7
# 342. Predicted: 1 Actual: 2
# 343. Predicted: 1 Actual: 8
# 344. Predicted: 1 Actual: 2
# 345. Predicted: 8 Actual: 2
# 346. Predicted: 1 Actual: 8
# 347. Predicted: 9 Actual: 9
# 348. Predicted: 1 Actual: 6
# 349. Predicted: 9 Actual: 3
# 350. Predicted: 1 Actual: 1
# 351. Predicted: 1 Actual: 8
# 352. Predicted: 1 Actual: 4
# 353. Predicted: 9 Actual: 3
# 354. Predicted: 1 Actual: 3
# 355. Predicted: 8 Actual: 5
# 356. Predicted: 1 Actual: 4
# 357. Predicted: 8 Actual: 0
# 358. Predicted: 8 Actual: 6
# 359. Predicted: 1 Actual: 7
# 360. Predicted: 8 Actual: 4
# 361. Predicted: 8 Actual: 8
# 362. Predicted: 1 Actual: 2
# 363. Predicted: 1 Actual: 4
# 364. Predicted: 1 Actual: 3
# 365. Predicted: 1 Actual: 9
# 366. Predicted: 1 Actual: 2
# 367. Predicted: 1 Actual: 3
# 368. Predicted: 9 Actual: 2
# 369. Predicted: 1 Actual: 1
# 370. Predicted: 1 Actual: 7
# 371. Predicted: 9 Actual: 9
# 372. Predicted: 1 Actual: 4
# 373. Predicted: 1 Actual: 5
# 374. Predicted: 1 Actual: 3
# 375. Predicted: 1 Actual: 8
# 376. Predicted: 1 Actual: 9
# 377. Predicted: 1 Actual: 3
# 378. Predicted: 1 Actual: 9
# 379. Predicted: 9 Actual: 4
# 380. Predicted: 1 Actual: 2
# 381. Predicted: 1 Actual: 5
# 382. Predicted: 1 Actual: 4
# 383. Predicted: 1 Actual: 5
# 384. Predicted: 1 Actual: 7
# 385. Predicted: 1 Actual: 7
# 386. Predicted: 1 Actual: 2
# 387. Predicted: 1 Actual: 7
# 388. Predicted: 1 Actual: 8
# 389. Predicted: 1 Actual: 7
# 390. Predicted: 1 Actual: 4
# 391. Predicted: 1 Actual: 1
# 392. Predicted: 1 Actual: 6
# 393. Predicted: 9 Actual: 3
# 394. Predicted: 1 Actual: 3
# 395. Predicted: 1 Actual: 0
# 396. Predicted: 1 Actual: 5
# 397. Predicted: 1 Actual: 9
# 398. Predicted: 1 Actual: 0
# 399. Predicted: 1 Actual: 2
# 400. Predicted: 1 Actual: 7
# 401. Predicted: 1 Actual: 8
# 402. Predicted: 8 Actual: 8
# 403. Predicted: 1 Actual: 2
# 404. Predicted: 1 Actual: 2
# 405. Predicted: 9 Actual: 6
# 406. Predicted: 8 Actual: 1
# 407. Predicted: 1 Actual: 4
# 408. Predicted: 1 Actual: 6
# 409. Predicted: 1 Actual: 1
# 410. Predicted: 1 Actual: 1
# 411. Predicted: 1 Actual: 7
# 412. Predicted: 1 Actual: 4
# 413. Predicted: 1 Actual: 0
# 414. Predicted: 1 Actual: 8
# 415. Predicted: 1 Actual: 0
# 416. Predicted: 1 Actual: 4
# 417. Predicted: 1 Actual: 1
# 418. Predicted: 1 Actual: 9
# 419. Predicted: 8 Actual: 9
# 420. Predicted: 8 Actual: 8
# 421. Predicted: 1 Actual: 9
# 422. Predicted: 1 Actual: 4
# 423. Predicted: 9 Actual: 0
# 424. Predicted: 1 Actual: 4
# 425. Predicted: 1 Actual: 8
# 426. Predicted: 1 Actual: 3
# 427. Predicted: 1 Actual: 8
# 428. Predicted: 9 Actual: 4
# 429. Predicted: 1 Actual: 8
# 430. Predicted: 1 Actual: 4
# 431. Predicted: 1 Actual: 9
# 432. Predicted: 8 Actual: 8
# 433. Predicted: 9 Actual: 7
# 434. Predicted: 1 Actual: 2
# 435. Predicted: 1 Actual: 2
# 436. Predicted: 8 Actual: 5
# 437. Predicted: 9 Actual: 3
# 438. Predicted: 1 Actual: 3
# 439. Predicted: 1 Actual: 6
# 440. Predicted: 8 Actual: 7
# 441. Predicted: 9 Actual: 9
# 442. Predicted: 1 Actual: 7
# 443. Predicted: 9 Actual: 2
# 444. Predicted: 1 Actual: 0
# 445. Predicted: 1 Actual: 4
# 446. Predicted: 1 Actual: 6
# 447. Predicted: 1 Actual: 7
# 448. Predicted: 8 Actual: 2
# 449. Predicted: 1 Actual: 7
# 450. Predicted: 1 Actual: 2
# 451. Predicted: 1 Actual: 5
# 452. Predicted: 1 Actual: 1
# Total Score: 60/453 = 13.25%
