# %%
import os
import numpy as np
import glob

# Import processing utils
import vidutils

# Import Pose Estimation Library
import cv2
from pytorch_openpose.src.body import Body

# %% [markdown]
# # Check Data Directory

# %%
data_path = ".\data"
video_folder = os.path.join(data_path, "videos")
video_list = os.listdir(video_folder)
print("Total Dance Videos in Dataset: {}".format(len(video_list)))
# Out:
# Total Dance Videos in Dataset: 4

# %%
# Check video count
for video in video_list:
    video_path = os.path.join(video_folder, video)
    video_count = len([fname for fname in os.listdir(video_path) if os.path.isfile(os.path.join(video_path, fname))])
    print("{}: {} videos".format(video, video_count))
    print("-"*50)
# Out:
# video1: 144 videos
# --------------------------------------------------
# video2: 120 videos
# --------------------------------------------------
# video3: 120 videos
# --------------------------------------------------
# video4: 120 videos
# --------------------------------------------------

# %% [markdown]
# # Extract Video Frames

# %%
# Number of Frames to Extract
n_frames = 20
frame_folder = os.path.join(data_path, "frames")
print(frame_folder)
# Out:
# .\data\frames

# %%
# Loop for all videos in data
for video in video_list:
    
    # Make path
    video_path = os.path.join(video_folder, video)
    #print("Current path: \'{}\'".format(video_path))
    
    # Obtain videos
    videos = [fname for fname in os.listdir(video_path) if os.path.isfile(os.path.join(video_path, fname))]
    
    # Extract Frames
    for video_file in videos:
        
        print("Extracting Frames for: {}".format(video_file))
        
        # Build Video Directory
        vf_path = os.path.join(video_path, video_file)
        #print(vf_path)
        
        # Build Frame Directory 
        frame_path = vf_path.replace(video_folder, frame_folder)
        frame_path = frame_path.replace(".mp4", "")
        #print(frame_path)
        
        # Check for contents
        os.makedirs(frame_path, exist_ok = True)
        frame_count = len(glob.glob1(frame_path,"*.jpg"))
        
        if frame_count == n_frames:
            print("Frames already extracted, skipping video")
        else:
            # Extract and Store Frames  
            vidutils.extract_frames(vf_path, frame_path, n_frames)
        
        print("-"*50)
# Out:
# Extracting Frames for: seg1_1a_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1a_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1a_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1a_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1a_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1a_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1b_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1b_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1c_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2a_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2a_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2a_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2a_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2a_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2a_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2b_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2b_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2b_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2b_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2c_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3a_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3a_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3b_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4a_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4b_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5a_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5a_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5a_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5a_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5b_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6a_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6a_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6a_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6a_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6b_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_1_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_1_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_1_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_1_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_1_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_1_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_1_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_1_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_1_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_1_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_2_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_2_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_2_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_2_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_2_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_2_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_2_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_2_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_2_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_2_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_3_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_3_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_3_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_3_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_3_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_3_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_3_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_3_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_3_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_3_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_4_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_4_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_4_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_4_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_4_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_4_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_4_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_4_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_4_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_4_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_5_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_5_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_5_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_5_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_5_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_5_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_5_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_5_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_5_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_5_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_6_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_6_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_6_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_6_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_6_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_6_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_6_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_6_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_6_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg3_6_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_1_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_1_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_1_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_1_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_1_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_1_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_1_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_1_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_1_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_1_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_2_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_2_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_2_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_2_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_2_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_2_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_2_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_2_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_2_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_2_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_3_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_3_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_3_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_3_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_3_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_3_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_3_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_3_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_3_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_3_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_4_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_4_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_4_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_4_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_4_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_4_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_4_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_4_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_4_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_4_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_5_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_5_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_5_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_5_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_5_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_5_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_5_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_5_7.mp4
# --------------------------------------------------
# Extracting Frames for: seg6_5_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_5_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_6_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_6_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_6_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_6_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_6_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_6_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_6_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_6_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_6_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg6_6_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_1_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_1_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_1_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_1_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_1_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_1_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_1_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_1_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_1_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_1_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_2_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_2_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_2_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_2_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_2_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_2_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_2_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_2_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_2_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_2_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_3_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_3_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_3_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_3_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_3_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_3_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_3_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_3_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_3_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_3_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_4_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_4_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_4_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_4_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_4_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_4_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_4_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_4_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_4_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_4_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_5_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_5_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_5_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_5_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_5_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_5_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_5_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_5_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_5_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_5_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_6_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_6_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_6_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_6_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_6_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_6_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_6_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_6_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_6_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg8_6_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_1_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_2_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_3_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_4_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_5_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg1_6_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_1_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_1_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_1_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_1_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_1_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_1_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_1_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_1_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_1_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_1_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_2_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_2_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_2_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_2_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_2_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_2_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_2_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_2_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_2_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_2_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_3_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_3_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_3_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_3_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_3_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_3_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_3_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_3_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_3_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_3_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_4_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_4_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_4_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_4_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_4_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_4_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_4_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_4_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_4_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_4_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_5_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_5_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_5_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_5_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_5_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_5_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_5_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_5_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_5_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_5_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_6_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# ...
# Extracting Frames for: seg5_6_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_6_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_6_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_6_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg5_6_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_1_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_1_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_1_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_1_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_1_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_1_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_1_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_1_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_1_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_1_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_2_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_2_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_2_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_2_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_2_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_2_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_2_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_2_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_2_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_2_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_3_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_3_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_3_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_3_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_3_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_3_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_3_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_3_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_3_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_3_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_4_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_4_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_4_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_4_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_4_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_4_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_4_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_4_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_4_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_4_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_5_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_5_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_5_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_5_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_5_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_5_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_5_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_5_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_5_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_5_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_6_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_6_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_6_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_6_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_6_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_6_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_6_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_6_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_6_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg4_6_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_1_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_1_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_1_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_1_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_1_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_1_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_1_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_1_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_1_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_1_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_2_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_2_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_2_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_2_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_2_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_2_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_2_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_2_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_2_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_2_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_3_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_3_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_3_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_3_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_3_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_3_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_3_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_3_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_3_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_3_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_4_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_4_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_4_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_4_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_4_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_4_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_4_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_4_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_4_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_4_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_5_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_5_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_5_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_5_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_5_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_5_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_5_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_5_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_5_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_5_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_6_0.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_6_1.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_6_2.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_6_3.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_6_4.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_6_5.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_6_6.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_6_7.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_6_8.mp4
# Frames already extracted, skipping video
# --------------------------------------------------
# Extracting Frames for: seg7_6_9.mp4
# Frames already extracted, skipping video
# --------------------------------------------------

# %% [markdown]
# # Estimate Poses from Frames

# %%
vf_list = os.listdir(frame_folder)
#print(vf_folder)    

# Check every video folder inside 'data/frames'
for vf_folder in vf_list:
    
    # Create path to video
    vf_path = os.path.join(frame_folder, vf_folder)
    print("Current Video: "+ vf_folder)
    
    # Get individual segment folder
    segfolder_list = os.listdir(vf_path)
    
    count = 1
    total = len(segfolder_list)
    
    # Check every segment folder
    for seg_folder in segfolder_list:
        
        # Create path to segment 
        seg_path = os.path.join(vf_path, seg_folder)
        print("Processing ({0}/{1}): {2}".format(count, total, seg_folder))
        
        # Check for features
        feature_file = os.path.join(seg_path, 'features.npz')
        if os.path.isfile(feature_file):
            print("Features already extracted, skipping folder")
        else:
            # Generate features_array for all frames
            features_array = vidutils.extract_pose_features_multi(seg_path, n_frames)
        
        count += 1
        print("---")
        
    print("-"*50)
# Out:
# Current Video: video1
# Processing (1/144): seg1_1a_1
# Features already extracted, skipping folder
# ---
# Processing (2/144): seg1_1a_2
# Features already extracted, skipping folder
# ---
# Processing (3/144): seg1_1a_4
# Features already extracted, skipping folder
# ---
# Processing (4/144): seg1_1a_5
# Features already extracted, skipping folder
# ---
# Processing (5/144): seg1_1a_8
# Features already extracted, skipping folder
# ---
# Processing (6/144): seg1_1a_9
# Features already extracted, skipping folder
# ---
# Processing (7/144): seg1_1b_1
# Features already extracted, skipping folder
# ---
# Processing (8/144): seg1_1b_5
# Features already extracted, skipping folder
# ---
# Processing (9/144): seg1_1c_5
# Features already extracted, skipping folder
# ---
# Processing (10/144): seg1_1_0
# Features already extracted, skipping folder
# ---
# Processing (11/144): seg1_1_1
# Features already extracted, skipping folder
# ---
# Processing (12/144): seg1_1_2
# Features already extracted, skipping folder
# ---
# Processing (13/144): seg1_1_3
# Features already extracted, skipping folder
# ---
# Processing (14/144): seg1_1_4
# Features already extracted, skipping folder
# ---
# Processing (15/144): seg1_1_5
# Features already extracted, skipping folder
# ---
# Processing (16/144): seg1_1_6
# Features already extracted, skipping folder
# ---
# Processing (17/144): seg1_1_8
# Features already extracted, skipping folder
# ---
# Processing (18/144): seg1_1_9
# Features already extracted, skipping folder
# ---
# Processing (19/144): seg1_2a_0
# Features already extracted, skipping folder
# ---
# Processing (20/144): seg1_2a_1
# Features already extracted, skipping folder
# ---
# Processing (21/144): seg1_2a_3
# Features already extracted, skipping folder
# ---
# Processing (22/144): seg1_2a_5
# Features already extracted, skipping folder
# ---
# Processing (23/144): seg1_2a_7
# Features already extracted, skipping folder
# ---
# Processing (24/144): seg1_2a_8
# Features already extracted, skipping folder
# ---
# Processing (25/144): seg1_2b_0
# Features already extracted, skipping folder
# ---
# Processing (26/144): seg1_2b_1
# Features already extracted, skipping folder
# ---
# Processing (27/144): seg1_2b_5
# Features already extracted, skipping folder
# ---
# Processing (28/144): seg1_2b_6
# Features already extracted, skipping folder
# ---
# Processing (29/144): seg1_2c_5
# Features already extracted, skipping folder
# ---
# Processing (30/144): seg1_2_0
# Features already extracted, skipping folder
# ---
# Processing (31/144): seg1_2_1
# Features already extracted, skipping folder
# ---
# Processing (32/144): seg1_2_3
# Features already extracted, skipping folder
# ---
# Processing (33/144): seg1_2_4
# Features already extracted, skipping folder
# ---
# Processing (34/144): seg1_2_5
# Features already extracted, skipping folder
# ---
# Processing (35/144): seg1_2_6
# Features already extracted, skipping folder
# ---
# Processing (36/144): seg1_2_7
# Features already extracted, skipping folder
# ---
# Processing (37/144): seg1_2_8
# Features already extracted, skipping folder
# ---
# Processing (38/144): seg1_2_9
# Features already extracted, skipping folder
# ---
# Processing (39/144): seg1_3a_2
# Features already extracted, skipping folder
# ---
# Processing (40/144): seg1_3a_7
# Features already extracted, skipping folder
# ---
# Processing (41/144): seg1_3b_7
# Features already extracted, skipping folder
# ---
# Processing (42/144): seg1_3_0
# Features already extracted, skipping folder
# ---
# Processing (43/144): seg1_3_1
# Features already extracted, skipping folder
# ---
# Processing (44/144): seg1_3_2
# Features already extracted, skipping folder
# ---
# Processing (45/144): seg1_3_3
# Features already extracted, skipping folder
# ---
# Processing (46/144): seg1_3_7
# Features already extracted, skipping folder
# ---
# Processing (47/144): seg1_3_9
# Features already extracted, skipping folder
# ---
# Processing (48/144): seg1_4a_9
# Features already extracted, skipping folder
# ---
# Processing (49/144): seg1_4b_9
# Features already extracted, skipping folder
# ---
# Processing (50/144): seg1_4_1
# Features already extracted, skipping folder
# ---
# Processing (51/144): seg1_4_2
# Features already extracted, skipping folder
# ---
# Processing (52/144): seg1_4_3
# Features already extracted, skipping folder
# ---
# Processing (53/144): seg1_4_4
# Features already extracted, skipping folder
# ---
# Processing (54/144): seg1_4_5
# Features already extracted, skipping folder
# ---
# Processing (55/144): seg1_4_6
# Features already extracted, skipping folder
# ---
# Processing (56/144): seg1_4_8
# Features already extracted, skipping folder
# ---
# Processing (57/144): seg1_4_9
# Features already extracted, skipping folder
# ---
# Processing (58/144): seg1_5a_3
# Features already extracted, skipping folder
# ---
# Processing (59/144): seg1_5a_4
# Features already extracted, skipping folder
# ---
# Processing (60/144): seg1_5a_8
# Features already extracted, skipping folder
# ---
# Processing (61/144): seg1_5a_9
# Features already extracted, skipping folder
# ---
# Processing (62/144): seg1_5b_8
# Features already extracted, skipping folder
# ---
# Processing (63/144): seg1_5_1
# Features already extracted, skipping folder
# ---
# Processing (64/144): seg1_5_2
# Features already extracted, skipping folder
# ---
# Processing (65/144): seg1_5_3
# Features already extracted, skipping folder
# ---
# Processing (66/144): seg1_5_4
# Features already extracted, skipping folder
# ---
# Processing (67/144): seg1_5_6
# Features already extracted, skipping folder
# ---
# Processing (68/144): seg1_5_7
# Features already extracted, skipping folder
# ---
# Processing (69/144): seg1_5_8
# Features already extracted, skipping folder
# ---
# Processing (70/144): seg1_5_9
# Features already extracted, skipping folder
# ---
# Processing (71/144): seg1_6a_1
# Features already extracted, skipping folder
# ---
# Processing (72/144): seg1_6a_4
# Features already extracted, skipping folder
# ---
# Processing (73/144): seg1_6a_7
# Features already extracted, skipping folder
# ---
# Processing (74/144): seg1_6a_8
# Features already extracted, skipping folder
# ---
# Processing (75/144): seg1_6b_1
# Features already extracted, skipping folder
# ---
# Processing (76/144): seg1_6_0
# Features already extracted, skipping folder
# ---
# Processing (77/144): seg1_6_1
# Features already extracted, skipping folder
# ---
# Processing (78/144): seg1_6_2
# Features already extracted, skipping folder
# ---
# Processing (79/144): seg1_6_3
# Features already extracted, skipping folder
# ---
# Processing (80/144): seg1_6_4
# Features already extracted, skipping folder
# ---
# Processing (81/144): seg1_6_6
# Features already extracted, skipping folder
# ---
# Processing (82/144): seg1_6_7
# Features already extracted, skipping folder
# ---
# Processing (83/144): seg1_6_8
# Features already extracted, skipping folder
# ---
# Processing (84/144): seg1_6_9
# Features already extracted, skipping folder
# ---
# Processing (85/144): seg3_1_0
# Features already extracted, skipping folder
# ---
# Processing (86/144): seg3_1_1
# Features already extracted, skipping folder
# ---
# Processing (87/144): seg3_1_2
# Features already extracted, skipping folder
# ---
# Processing (88/144): seg3_1_3
# Features already extracted, skipping folder
# ---
# Processing (89/144): seg3_1_4
# Features already extracted, skipping folder
# ---
# Processing (90/144): seg3_1_5
# Features already extracted, skipping folder
# ---
# Processing (91/144): seg3_1_6
# Features already extracted, skipping folder
# ---
# Processing (92/144): seg3_1_7
# Features already extracted, skipping folder
# ---
# Processing (93/144): seg3_1_8
# Features already extracted, skipping folder
# ---
# Processing (94/144): seg3_1_9
# Features already extracted, skipping folder
# ---
# Processing (95/144): seg3_2_0
# Features already extracted, skipping folder
# ---
# Processing (96/144): seg3_2_1
# Features already extracted, skipping folder
# ---
# Processing (97/144): seg3_2_2
# Features already extracted, skipping folder
# ---
# Processing (98/144): seg3_2_3
# Features already extracted, skipping folder
# ---
# Processing (99/144): seg3_2_4
# Features already extracted, skipping folder
# ---
# Processing (100/144): seg3_2_5
# Features already extracted, skipping folder
# ---
# Processing (101/144): seg3_2_6
# Features already extracted, skipping folder
# ---
# Processing (102/144): seg3_2_7
# Features already extracted, skipping folder
# ---
# Processing (103/144): seg3_2_8
# Features already extracted, skipping folder
# ---
# Processing (104/144): seg3_2_9
# Features already extracted, skipping folder
# ---
# Processing (105/144): seg3_3_0
# Features already extracted, skipping folder
# ---
# Processing (106/144): seg3_3_1
# Features already extracted, skipping folder
# ---
# Processing (107/144): seg3_3_2
# Features already extracted, skipping folder
# ---
# Processing (108/144): seg3_3_3
# Features already extracted, skipping folder
# ---
# Processing (109/144): seg3_3_4
# Features already extracted, skipping folder
# ---
# Processing (110/144): seg3_3_5
# Features already extracted, skipping folder
# ---
# Processing (111/144): seg3_3_6
# Features already extracted, skipping folder
# ---
# Processing (112/144): seg3_3_7
# Features already extracted, skipping folder
# ---
# Processing (113/144): seg3_3_8
# Features already extracted, skipping folder
# ---
# Processing (114/144): seg3_3_9
# Features already extracted, skipping folder
# ---
# Processing (115/144): seg3_4_0
# Features already extracted, skipping folder
# ---
# Processing (116/144): seg3_4_1
# Features already extracted, skipping folder
# ---
# Processing (117/144): seg3_4_2
# Features already extracted, skipping folder
# ---
# Processing (118/144): seg3_4_3
# Features already extracted, skipping folder
# ---
# Processing (119/144): seg3_4_4
# Features already extracted, skipping folder
# ---
# Processing (120/144): seg3_4_5
# Features already extracted, skipping folder
# ---
# Processing (121/144): seg3_4_6
# Features already extracted, skipping folder
# ---
# Processing (122/144): seg3_4_7
# Features already extracted, skipping folder
# ---
# Processing (123/144): seg3_4_8
# Features already extracted, skipping folder
# ---
# Processing (124/144): seg3_4_9
# Features already extracted, skipping folder
# ---
# Processing (125/144): seg3_5_0
# Features already extracted, skipping folder
# ---
# Processing (126/144): seg3_5_1
# Features already extracted, skipping folder
# ---
# Processing (127/144): seg3_5_2
# Features already extracted, skipping folder
# ---
# Processing (128/144): seg3_5_3
# Features already extracted, skipping folder
# ---
# Processing (129/144): seg3_5_4
# Features already extracted, skipping folder
# ---
# Processing (130/144): seg3_5_5
# Features already extracted, skipping folder
# ---
# Processing (131/144): seg3_5_6
# Features already extracted, skipping folder
# ---
# Processing (132/144): seg3_5_7
# Features already extracted, skipping folder
# ---
# Processing (133/144): seg3_5_8
# Features already extracted, skipping folder
# ---
# Processing (134/144): seg3_5_9
# Features already extracted, skipping folder
# ---
# Processing (135/144): seg3_6_0
# Features already extracted, skipping folder
# ---
# Processing (136/144): seg3_6_1
# Features already extracted, skipping folder
# ---
# Processing (137/144): seg3_6_2
# Features already extracted, skipping folder
# ---
# Processing (138/144): seg3_6_3
# Features already extracted, skipping folder
# ---
# Processing (139/144): seg3_6_4
# Features already extracted, skipping folder
# ---
# Processing (140/144): seg3_6_5
# Features already extracted, skipping folder
# ---
# Processing (141/144): seg3_6_6
# Features already extracted, skipping folder
# ---
# Processing (142/144): seg3_6_7
# Features already extracted, skipping folder
# ---
# Processing (143/144): seg3_6_8
# Features already extracted, skipping folder
# ---
# Processing (144/144): seg3_6_9
# Features already extracted, skipping folder
# ---
# --------------------------------------------------
# Current Video: video2
# Processing (1/120): seg6_1_0
# Features already extracted, skipping folder
# ---
# Processing (2/120): seg6_1_1
# Features already extracted, skipping folder
# ---
# Processing (3/120): seg6_1_2
# Features already extracted, skipping folder
# ---
# Processing (4/120): seg6_1_3
# Features already extracted, skipping folder
# ---
# Processing (5/120): seg6_1_4
# Features already extracted, skipping folder
# ---
# Processing (6/120): seg6_1_5
# Features already extracted, skipping folder
# ---
# Processing (7/120): seg6_1_6
# Features already extracted, skipping folder
# ---
# Processing (8/120): seg6_1_7
# Features already extracted, skipping folder
# ---
# Processing (9/120): seg6_1_8
# Features already extracted, skipping folder
# ---
# Processing (10/120): seg6_1_9
# Features already extracted, skipping folder
# ---
# Processing (11/120): seg6_2_0
# Features already extracted, skipping folder
# ---
# Processing (12/120): seg6_2_1
# Features already extracted, skipping folder
# ---
# Processing (13/120): seg6_2_2
# Features already extracted, skipping folder
# ---
# Processing (14/120): seg6_2_3
# Features already extracted, skipping folder
# ---
# Processing (15/120): seg6_2_4
# Features already extracted, skipping folder
# ---
# Processing (16/120): seg6_2_5
# Features already extracted, skipping folder
# ---
# Processing (17/120): seg6_2_6
# Features already extracted, skipping folder
# ---
# Processing (18/120): seg6_2_7
# Features already extracted, skipping folder
# ---
# Processing (19/120): seg6_2_8
# Features already extracted, skipping folder
# ---
# Processing (20/120): seg6_2_9
# Features already extracted, skipping folder
# ---
# Processing (21/120): seg6_3_0
# Features already extracted, skipping folder
# ---
# Processing (22/120): seg6_3_1
# Features already extracted, skipping folder
# ---
# Processing (23/120): seg6_3_2
# Features already extracted, skipping folder
# ---
# Processing (24/120): seg6_3_3
# Features already extracted, skipping folder
# ---
# Processing (25/120): seg6_3_4
# Features already extracted, skipping folder
# ---
# Processing (26/120): seg6_3_5
# Features already extracted, skipping folder
# ---
# Processing (27/120): seg6_3_6
# Features already extracted, skipping folder
# ---
# Processing (28/120): seg6_3_7
# Features already extracted, skipping folder
# ---
# Processing (29/120): seg6_3_8
# Features already extracted, skipping folder
# ---
# Processing (30/120): seg6_3_9
# Features already extracted, skipping folder
# ---
# Processing (31/120): seg6_4_0
# Features already extracted, skipping folder
# ---
# Processing (32/120): seg6_4_1
# Features already extracted, skipping folder
# ---
# Processing (33/120): seg6_4_2
# Features already extracted, skipping folder
# ---
# Processing (34/120): seg6_4_3
# Features already extracted, skipping folder
# ---
# Processing (35/120): seg6_4_4
# Features already extracted, skipping folder
# ---
# Processing (36/120): seg6_4_5
# Features already extracted, skipping folder
# ---
# Processing (37/120): seg6_4_6
# Features already extracted, skipping folder
# ---
# Processing (38/120): seg6_4_7
# Features already extracted, skipping folder
# ---
# Processing (39/120): seg6_4_8
# Features already extracted, skipping folder
# ---
# Processing (40/120): seg6_4_9
# Features already extracted, skipping folder
# ---
# Processing (41/120): seg6_5_0
# Features already extracted, skipping folder
# ---
# Processing (42/120): seg6_5_1
# Features already extracted, skipping folder
# ---
# Processing (43/120): seg6_5_2
# Features already extracted, skipping folder
# ---
# Processing (44/120): seg6_5_3
# Features already extracted, skipping folder
# ---
# Processing (45/120): seg6_5_4
# Features already extracted, skipping folder
# ---
# Processing (46/120): seg6_5_5
# Features already extracted, skipping folder
# ---
# Processing (47/120): seg6_5_6
# Features already extracted, skipping folder
# ---
# Processing (48/120): seg6_5_7
# Features already extracted, skipping folder
# ---
# Processing (49/120): seg6_5_8
# ---
# Processing (50/120): seg6_5_9
# ---
# Processing (51/120): seg6_6_0
# ---
# Processing (52/120): seg6_6_1
# ---
# Processing (53/120): seg6_6_2
# ---
# Processing (54/120): seg6_6_3
# ---
# Processing (55/120): seg6_6_4
# ---
# Processing (56/120): seg6_6_5
# ---
# Processing (57/120): seg6_6_6
# ---
# Processing (58/120): seg6_6_7
# ---
# Processing (59/120): seg6_6_8
# **********
# Warning: OpenPose recognizes 2/3 people in frame. Adding missing data.
# .\data\frames\video2\seg6_6_8\frame19.jpg
# **********
# ---
# Processing (60/120): seg6_6_9
# ---
# Processing (61/120): seg8_1_0
# ---
# Processing (62/120): seg8_1_1
# ---
# Processing (63/120): seg8_1_2
# ---
# Processing (64/120): seg8_1_3
# ---
# Processing (65/120): seg8_1_4
# ---
# Processing (66/120): seg8_1_5
# ---
# Processing (67/120): seg8_1_6
# ---
# Processing (68/120): seg8_1_7
# ---
# Processing (69/120): seg8_1_8
# ---
# Processing (70/120): seg8_1_9
# ---
# Processing (71/120): seg8_2_0
# ---
# Processing (72/120): seg8_2_1
# ---
# Processing (73/120): seg8_2_2
# ---
# Processing (74/120): seg8_2_3
# ---
# Processing (75/120): seg8_2_4
# ---
# Processing (76/120): seg8_2_5
# ---
# Processing (77/120): seg8_2_6
# ---
# Processing (78/120): seg8_2_7
# ---
# Processing (79/120): seg8_2_8
# ---
# Processing (80/120): seg8_2_9
# ---
# Processing (81/120): seg8_3_0
# ---
# Processing (82/120): seg8_3_1
# ---
# Processing (83/120): seg8_3_2
# ---
# Processing (84/120): seg8_3_3
# ---
# Processing (85/120): seg8_3_4
# ---
# Processing (86/120): seg8_3_5
# ---
